# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
forwards = pd.read_csv('data/forwards.csv')
midfielders = pd.read_csv('data/midfielders.csv')
defenders = pd.read_csv('data/defenders.csv')
goalkeepers = pd.read_csv('data/goalkeepers.csv')

# %%
forwards.head(2)
# Out:
#    player_id                   player_name  mob  dob   yob         positions  \
# 0      20801  C. Ronaldo dos Santos Aveiro  Feb    5  1985  ["'LW'", "'ST'"]
# 1     158023                  Lionel Messi  Jun   24  1987          ["'RW'"]
#
#     body_type        work_rate preferred_foot  age     ...       composure  \
# 0  C. Ronaldo       High / Low          Right   31     ...              86
# 1       Messi  Medium / Medium           Left   29     ...              94
#
#    marking  standing_tackle  sliding_tackle  gk_diving  gk_handling  \
# 0       22               31              23          7           11
# 1       13               28              26          6           11
#
#    gk_kicking  gk_positioning  gk_reflexes  player_type
# 0          15              14           11      forward
# 1          15              14            8      forward
#
# [2 rows x 54 columns]

# %%
plt.figure(1)
plt.figure(figsize=(20, 10), dpi=100)
plt.scatter(forwards['acceleration'], forwards['sprint_speed'])
plt.xlabel('acceleration')
plt.ylabel('sprint speed')
plt.show()

# %%
plt.figure(2)
plt.figure(figsize=(20, 10), dpi=100)
plt.scatter(forwards['finishing'], forwards['free_kick_accuracy'])
plt.xlabel('finishing')
plt.ylabel('free kick accuracy')
plt.show()

# %%
plt.figure(3)
plt.figure(figsize=(20, 10), dpi=100)
plt.scatter(midfielders['dribbling'], midfielders['long_passing'])
plt.xlabel('finishing')
plt.ylabel('free kick accuracy')
plt.show()

# %%
list(forwards.columns.values)
# Out:
# ['player_id',
#  'player_name',
#  'mob',
#  'dob',
#  'yob',
#  'positions',
#  'body_type',
#  'work_rate',
#  'preferred_foot',
#  'age',
#  'weight',
#  'height',
#  'overall_rating',
#  'potential',
#  'value',
#  'wage',
#  'intl_reputation',
#  'weak_foot',
#  'skill_moves',
#  'crossing',
#  'finishing',
#  'heading_accuracy',
#  'short_passing',
#  'volleys',
#  'dribbling',
#  'curve',
#  'free_kick_accuracy',
#  'long_passing',
#  'ball_control',
#  'acceleration',
#  'sprint_speed',
#  'agility',
#  'reactions',
#  'balance',
#  'shot_power',
#  'jumping',
#  'stamina',
#  'strength',
#  'long_shots',
#  'aggression',
#  'interceptions',
#  'positioning',
#  'vision',
#  'penalties',
#  'composure',
#  'marking',
#  'standing_tackle',
#  'sliding_tackle',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_positioning',
#  'gk_reflexes',
#  'player_type']
