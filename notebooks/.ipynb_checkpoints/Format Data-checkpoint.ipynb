# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

# %%
players = pd.read_csv('../data/players.csv')

# %%
players.head()
# Out:
#    player_id                   player_name  mob  dob   yob     positions  \
# 0      20801  C. Ronaldo dos Santos Aveiro  Feb    5  1985  ['LW', 'ST']
# 1     158023                  Lionel Messi  Jun   24  1987        ['RW']
# 2     190871    Neymar da Silva Santos Jr.  Feb    5  1992        ['LW']
# 3     176580                   Luis Suárez  Jan   24  1987        ['ST']
# 4     167495                  Manuel Neuer  Mar   27  1986        ['GK']
#
#     body_type        work_rate preferred_foot  age     ...       penalties  \
# 0  C. Ronaldo       High / Low          Right   31     ...              85
# 1       Messi  Medium / Medium           Left   29     ...              74
# 2      Neymar    High / Medium          Right   24     ...              81
# 3      Normal    High / Medium          Right   29     ...              85
# 4      Normal  Medium / Medium          Right   30     ...              47
#
#    composure  marking  standing_tackle  sliding_tackle  gk_diving  \
# 0         86       22               31              23          7
# 1         94       13               28              26          6
# 2         80       21               24              33          9
# 3         83       30               45              38         27
# 4         70       10               10              11         89
#
#    gk_handling  gk_kicking  gk_positioning  gk_reflexes
# 0           11          15              14           11
# 1           11          15              14            8
# 2            9          15              15           11
# 3           25          31              33           37
# 4           90          95              91           89
#
# [5 rows x 53 columns]

# %%
def format_positions(positions):
    pos_arr = positions.replace('[', '').replace(']', '').split(',')
    mod_pos = []
    for pos in pos_arr:
        mod_pos.append(pos.strip())
    return mod_pos

mod_pos = players['positions'].apply(format_positions)
players['positions'] = mod_pos

# %%
pos_set = []
for idx, row in players.iterrows():
    positions = row['positions']
    for pos in positions:
        if pos not in pos_set:
            pos_set.append(pos)

# %%
forwards = ["'ST'", "'LW'", "'RW'", "'CF'"]
midfielders = ["'CM'", "'LM'", "'RM'", "'CDM'", "'CAM'"]
defenders = ["'CB'", "'RB'", "'LB'", "'RWB'", "'LWB'"]
goalkeepers = ["'GK'"]

player_type = []
for pos_list in players['positions']:
    if pos_list[0] in forwards:
        player_type.append('forward')
    elif pos_list[0] in midfielders:
        player_type.append('midfielder')
    elif pos_list[0] in defenders:
        player_type.append('defender')
    elif pos_list[0] in goalkeepers:
        player_type.append('goalkeeper')

players['player_type'] = player_type

# %%
workrate_set = []
for idx, row in players.iterrows():
    work_rate = row['work_rate']
    if work_rate not in workrate_set:
        workrate_set.append(work_rate)            

# for w in workrate_set:
#     print(w)

# %%
players.head()
# Out:
#    player_id                   player_name  mob  dob   yob     positions  \
# 0      20801  C. Ronaldo dos Santos Aveiro  Feb    5  1985  ['LW', 'ST']
# 1     158023                  Lionel Messi  Jun   24  1987        ['RW']
# 2     190871    Neymar da Silva Santos Jr.  Feb    5  1992        ['LW']
# 3     176580                   Luis Suárez  Jan   24  1987        ['ST']
# 4     167495                  Manuel Neuer  Mar   27  1986        ['GK']
#
#     body_type        work_rate preferred_foot  age     ...       composure  \
# 0  C. Ronaldo       High / Low          Right   31     ...              86
# 1       Messi  Medium / Medium           Left   29     ...              94
# 2      Neymar    High / Medium          Right   24     ...              80
# 3      Normal    High / Medium          Right   29     ...              83
# 4      Normal  Medium / Medium          Right   30     ...              70
#
#    marking  standing_tackle  sliding_tackle  gk_diving  gk_handling  \
# 0       22               31              23          7           11
# 1       13               28              26          6           11
# 2       21               24              33          9            9
# 3       30               45              38         27           25
# 4       10               10              11         89           90
#
#    gk_kicking  gk_positioning  gk_reflexes  player_type
# 0          15              14           11      forward
# 1          15              14            8      forward
# 2          15              15           11      forward
# 3          31              33           37      forward
# 4          95              91           89   goalkeeper
#
# [5 rows x 54 columns]

# %%
list(players.columns.values)
# Out:
# ['player_id',
#  'player_name',
#  'mob',
#  'dob',
#  'yob',
#  'positions',
#  'body_type',
#  'work_rate',
#  'preferred_foot',
#  'age',
#  'weight',
#  'height',
#  'overall_rating',
#  'potential',
#  'value',
#  'wage',
#  'intl_reputation',
#  'weak_foot',
#  'skill_moves',
#  'crossing',
#  'finishing',
#  'heading_accuracy',
#  'short_passing',
#  'volleys',
#  'dribbling',
#  'curve',
#  'free_kick_accuracy',
#  'long_passing',
#  'ball_control',
#  'acceleration',
#  'sprint_speed',
#  'agility',
#  'reactions',
#  'balance',
#  'shot_power',
#  'jumping',
#  'stamina',
#  'strength',
#  'long_shots',
#  'aggression',
#  'interceptions',
#  'positioning',
#  'vision',
#  'penalties',
#  'composure',
#  'marking',
#  'standing_tackle',
#  'sliding_tackle',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_positioning',
#  'gk_reflexes',
#  'player_type']

# %%
forwards_frame = players.loc[players['player_type'] == 'forward']
midfielders_frame = players.loc[players['player_type'] == 'midfielder']
defenders_frame = players.loc[players['player_type'] == 'defender']
goalkeepers_frame = players.loc[players['player_type'] == 'goalkeeper']

forwards_frame.to_csv('../data/forwards.csv', index=False)
midfielders_frame.to_csv('../data/midfielders.csv', index=False)
defenders_frame.to_csv('../data/defenders.csv', index=False)
goalkeepers_frame.to_csv('../data/goalkeepers.csv', index=False)

# %%
unwanted_columns = ['player_name', 'mob', 'dob', 'yob', 'positions', 'body_type', 'work_rate', 'preferred_foot', 'player_type']
for col in unwanted_columns:
    forwards_frame = forwards_frame.drop(col, axis=1)
    midfielders_frame = midfielders_frame.drop(col, axis=1)
    defenders_frame = defenders_frame.drop(col, axis=1)
    goalkeepers_frame = goalkeepers_frame.drop(col, axis=1)
print(forwards_frame..columns.values)
# Out:
#        player_id  age  weight  height  overall_rating  potential       value  \
# 0          20801   31    80.0   185.0            94.0       94.0     87000.0
# 1         158023   29    72.0   170.0            93.0       93.0     89000.0
# 2         190871   24    68.0   174.0            92.0       94.0    106000.0
# 3         176580   29    85.0   182.0            92.0       92.0     83000.0
# 6         188545   27    79.0   185.0            90.0       90.0     71000.0
# 7         173731   26    74.0   183.0            90.0       90.0     72000.0
# 8          41236   34    95.0   195.0            90.0       90.0     36500.0
# 11        183277   25    74.0   173.0            89.0       90.0     71500.0
# 14        167664   28    87.0   184.0            89.0       89.0     61500.0
# 17        153079   28    70.0   173.0            89.0       89.0     61500.0
# 19        194765   25    67.0   176.0            88.0       91.0     66500.0
# 17631     236528   16    78.0   191.0            45.0       67.0  70000000.0
#
#               wage  intl_reputation  weak_foot     ...       penalties  \
# 0      340000000.0                5          4     ...              85
# 1      340000000.0                5          4     ...              74
# 2      260000000.0                5          5     ...              81
# 3      255000000.0                5          4     ...              85
# 6      210000000.0                4          4     ...              81
# 7      210000000.0                4          3     ...              76
# 8      150000000.0                5          4     ...              91
# 11     180000000.0                4          4     ...              86
# 14     210000000.0                4          4     ...              70
# 17     210000000.0                4          4     ...              80
# 19     160000000.0                4          3     ...              71
# 22     180000000.0                4          3     ...              77
# 35     160000000.0                3          4     ...              82
# 43     120000000.0                3          3     ...              86
# 49     170000000.0                4          4     ...              60
# 53     130000000.0                3          4     ...              64
# 54     170000000.0                4          2     ...              73
# 55     170000000.0                4          4     ...              76
# 56     140000000.0                4          3     ...              84
# 62     170000000.0                4          4     ...              82
# 67     100000000.0                3          3     ...              82
# 68     110000000.0                3          4     ...              84
# 70     110000000.0                3          4     ...              80
# 78     110000000.0                3          4     ...              78
# 90     110000000.0                3          4     ...              78
# 92     110000000.0                2          3     ...              61
# 118     70000000.0                2          3     ...              77
# 128    100000000.0                3          2     ...              80
# 133     90000000.0                2          4     ...              72
# 143     70000000.0                2          3     ...              80
# ...            ...              ...        ...     ...             ...
# 17387    1000000.0                1          3     ...              61
# 17390    1000000.0                1          3     ...              60
# 17392    1000000.0                1          3     ...              59
# 17405    1000000.0                1          3     ...              57
# 17410    1000000.0                1          3     ...              60
# 17412    1000000.0                1          3     ...              59
# 17414    1000000.0                1          2     ...              54
# 17434    1000000.0                1          2     ...              64
# 17437    1000000.0                1          3     ...              49
# 17440    1000000.0                1          3     ...              58
# 17447    1000000.0                1          3     ...              64
# 17466    1000000.0                1          2     ...              51
# 17483    1000000.0                1          3     ...              54
# 17488    1000000.0                1          3     ...              47
# 17505    1000000.0                1          3     ...              52
# 17510    1000000.0                1          2     ...              60
# 17521    1000000.0                1          2     ...              56
# 17529    1000000.0                1          3     ...              50
# 17534    1000000.0                1          3     ...              53
# 17537    1000000.0                1          3     ...              59
# 17539    1000000.0                1          2     ...              50
# 17551    1000000.0                1          2     ...              47
# 17574    1000000.0                1          3     ...              58
# 17575    1000000.0                1          3     ...              59
# 17577    1000000.0                1          2     ...              58
# 17591    1000000.0                1          3     ...              57
# 17597    1000000.0                1          2     ...              49
# 17602    1000000.0                1          2     ...              39
# 17611    1000000.0                1          2     ...              62
# 17631    1000000.0                1          3     ...              40
#
#        composure  marking  standing_tackle  sliding_tackle  gk_diving  \
# 0             86       22               31              23          7
# 1             94       13               28              26          6
# 2             80       21               24              33          9
# 3             83       30               45              38         27
# 6             87       25               42              19         15
# 7             85       51               55              52         15
# 8             91       15               41              27         13
# 11            86       25               27              22         11
# 14            84       12               22              18          5
# 17            90       13               20              12         13
# 19            81       23               22              11         14
# 22            82       30               39              35         10
# 35            79       28               25              36          6
# 43            82       14               20              20          5
# 49            83       31               41              44          6
# 53            79       24               44              40         12
# 54            80       37               59              56         10
# 55            84       28               39              34         11
# 56            81       24               45              27         12
# 62            82       13               15              12         13
# 67            83       41               36              38          8
# 68            86       23               42              30         11
# 70            84       27               30              30          8
# 78            75       30               40              40          7
# 90            76       17               21              21         13
# 92            72       16               24              22          8
# 118           87       46               44              49         14
# 128           80       12               16              14         12
# 133           76       30               64              42          8
# 143           69       20               21              18         12
# ...          ...      ...              ...             ...        ...
# 17387         45       19               18              14          7
# 17390         47       10               15              13         15
# 17392         43       10               12              19          6
# 17405         48       13               16              18         13
# 17410         42       12               10              14          9
# 17412         49       16               16              10         15
# 17414         41       17               15              18         11
# 17434         48       17               19              11         10
# 17437         45       25               36              34         10
# 17440         45       20               19              18         12
# 17447         52       16               10              11         10
# 17466         46       15               15              17          6
# 17483         43       14               19              16         12
# 17488         44       19               23              24          8
# 17505         47       24               32              27         13
# 17510         43       14               10              11         15
# 17521         41       15               12              18         11
# 17529         43       20               27              22          9
# 17534         43       18               30              21          7
# 17537         43       19               12              16          9
# 17539         42       26               27              27         13
# 17551         45       18               27              21          7
# 17574         45       13               17              15         12
# 17575         42       12               13              11         10
# 17577         46       12               10              13          8
# 17591         40       16               18              17         10
# 17597         47       16               18              10         11
# 17602         47       22               33              31          8
# 17611         46       18               14              17         15
# 17631         43       13               16              15          7
#
#        gk_handling  gk_kicking  gk_positioning  gk_reflexes
# 0               11          15              14           11
# 1               11          15              14            8
# 2                9          15              15           11
# 3               25          31              33           37
# 6                6          12               8           10
# 7               15          11               5            6
# 8               15          10               9           12
# 11              12           6               8            8
# 14              12           7               5           10
# 17              15           6              11           14
# 19               8          14              13           14
# 22              10          15              12           13
# 35               9          15               9            9
# 43               4           4               5            8
# 49               7          11              14           14
# 53               7           9              14            6
# 54               7          11              12           11
# 55              13          12               8           11
# 56               5          13              13           10
# 62              11           5               5            7
# 67              10          11              14           11
# 68               6           9               5            6
# 70              15          14               7           10
# 78              10           8              10            4
# 90               9           5               7            9
# 92               4          14               9           10
# 118             10           9              15            9
# 128             12           8               5            8
# 133             11           9               6           10
# 143             16           9              12           13
# ...            ...         ...             ...          ...
# 17387            7           9              12           16
# 17390            8           8              12           14
# 17392           11          13               8            7
# 17405            7          15               7           10
# 17410            8          11              11           14
# 17412           13           7              13            8
# 17414           11           9               6           14
# 17434            8           9               8           10
# 17437            8          15              10           13
# 17440            9          13              11           10
# 17447           11          11              13            9
# 17466            8           9              13           10
# 17483           14          12               7            9
# 17488            7           7              15           15
# 17505           15          14               7            8
# 17510           13          11               9            8
# 17521           14          10              10            9
# 17529           10          10              11            7
# 17534            8           8              14           13
# 17537            5           7               9            7
# 17539            8           7              14            9
# 17551           12           7              13           10
# 17574           10          14              13           15
# 17575           13           6              14            6
# 17577            7          11               8            5
# 17591           10           7              11            9
# 17597           10           5              12            9
# 17602           16          15              14            9
# 17611           11          13               9            6
# 17631           12          14              12            7
#
# [3294 rows x 45 columns]

# %%
np.save('../data/forwards', forwards_frame)
np.save('../data/midfielders', midfielders_frame)
np.save('../data/defenders', defenders_frame)
np.save('../data/goalkeepers', goalkeepers_frame)
